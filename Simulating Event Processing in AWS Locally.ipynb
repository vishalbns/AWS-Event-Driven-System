# %% [markdown]
# # Simulating Event Processing in AWS Locally
#
# **Introduction**: In this notebook, I simulate an event processing pipeline similar to what would be implemented using AWS services like EventBridge, Lambda, S3, CloudWatch, and Dead Letter Queue (DLQ). I simulate event generation, validation, processing, anomaly detection, and failure handling with retries. The goal is to mimic the core functionalities in a local environment for better understanding and testing of the entire event-driven architecture.

# %%
import random
import json
import time
import uuid
from datetime import datetime

# %% [markdown]
# Simulating Event Generation Here, we generate simulated customer event data.
# Each event includes attributes like eventId, customerId, salesRepId, eventType, and other details.
# A random selection is made for different event types and platforms.
# Additionally, a percentage of faulty events is introduced to simulate real-world data irregularities.

# %%
# ------------------- Simulate Event Generation -------------------

def generate_customer_event(i):
    customer_ids = ["C123", "C456", "C789", "C101", "C112"]
    sales_rep_ids = ["SR001", "SR002", "SR003", "SR004"]
    event_types = ["app_open", "inquiry", "meeting_scheduled", "call_logged", "ticket_created", "ticket_resolved"]

    event = {
        "eventId": 100000 + i,
        "customerId": random.choice(customer_ids),
        "salesRepId": random.choice(sales_rep_ids),
        "eventType": random.choice(event_types),
        "eventDetails": "Details about the event",
        "timestamp": datetime.now().isoformat(),
        "platform": random.choice(["iOS", "Android"]),
        "region": random.choice(["US", "EU", "IN", "APAC"]),
    }

    # Ensure a percentage of faulty events
    prob = random.random()
    
    if prob < 0.1:  
        event["customerId"] = None  # 10% missing customerId (critical failure)
    elif prob < 0.2:
        event["eventType"] = None  # 10% missing eventType (critical failure)
    elif prob < 0.3:
        event["platform"] = "Windows"  # 10% invalid platform (anomaly/ incorrect business data)

    return event

# %% [markdown]
# CloudWatch Logging Function This cell simulates logging messages to AWS CloudWatch. Logs are stored in a list and printed to the console to give a visual representation of CloudWatch logs, which would normally be handled by the AWS SDK for Python (Boto3).

# %%
# ------------------- CloudWatch Logging Function -------------------
logs = []
def log_cloudwatch(message):
    """
    Simulates logging a message to CloudWatch.
    """
    # In a real scenario, you would use AWS SDK for Python (Boto3) to log to CloudWatch Logs
    logs.append(message)
    print(f"[CloudWatch Log] {message}")

# %% [markdown]
# Mock Dead Letter Queue (DLQ) This function simulates sending failed events to a Dead Letter Queue (DLQ). Events that fail validation or processing steps are logged with the reason for failure and stored in the dlq list for later investigation.

# %%
# ------------------- Mock Dead Letter Queue (DLQ) -------------------
dlq = []  # Stores events that failed

def send_to_dlq(event, reason="Unknown"):
    """
    Sends the failed event to the Dead Letter Queue (DLQ) for further analysis.
    Includes a reason for failure.
    """
    global dlq
    
    event_with_reason = event.copy()
    event_with_reason["failure_reason"] = reason  # Attach failure reason
    
    dlq.append(event_with_reason)  # Store event in DLQ
    
    log_cloudwatch(f"Event {event['eventId']} sent to DLQ due to: {reason}.")

# %% [markdown]
# EventBridge Rule Check Function This function simulates the validation of events against EventBridge rules. The check ensures that all required fields are present in the event. If any field is missing, the event is flagged and sent to the DLQ for further review.

# %%
# ------------------- EventBridge Rule Check Function -------------------

def eventbridge_rule_check(event):
    """
    Basic structure validation for event routing via EventBridge (only checks if values are there).
    Logs to CloudWatch.
    """
    global event_bus
    required_fields = ['eventId', 'customerId', 'salesRepId', 'eventType', 'timestamp', 'platform', 'region']
    
    for field in required_fields:
        if field not in event:
            log_cloudwatch(f"EventBridge validation failed: Missing required field '{field}' in event {event['eventId']}. Sent to DLQ")
            #move_to_dlq(event, "EventBridge Rule")
            return False
    
    log_cloudwatch(f"EventBridge rule validation passed for event {event['eventId']}.")
    return True

# %% [markdown]
# Lambda Validation Check Function This cell simulates the validation logic that would be applied to events within an AWS Lambda function. It checks for missing or invalid values in the event data (e.g., customerId, eventType). Events failing this validation are moved to the DLQ.

# %%
# ------------------- Lambda Validation Check Function -------------------

def lambda_validation_check(event):
    """
    Validates the event in the Lambda function based on business logic.
    Logs to CloudWatch.
    """
    if event['customerId'] is None or event['customerId'] == "":
        log_cloudwatch(f"Lambda validation failed: Missing or invalid 'customerId' in event {event['eventId']}. Sending to DLQ")
        #send_to_dlq(event, "Lambda validation Rule")
        return False

    if event['eventType'] is None or event['eventType'] == "":
        log_cloudwatch(f"Lambda validation failed: Missing or invalid 'eventType' in event {event['eventId']}. Sending to DLQ")
        #send_to_dlq(event, "Lambda validation Rule")
        return False

    valid_event_types = ["app_open", "inquiry", "meeting_scheduled", "call_logged", "ticket_created", "ticket_resolved"]
    if event['eventType'] not in valid_event_types:
        log_cloudwatch(f"Lambda validation failed: Invalid 'eventType' {event['eventType']} in event {event['eventId']}. Sending to DLQ")
        #send_to_dlq(event, "Lambda validation Rule")
        return False
    
    log_cloudwatch(f"Lambda validation passed for event {event['eventId']}.")
    return True

# %% [markdown]
# Mock S3 Storage Simulates the storage of events in AWS S3. Events are stored based on whether they are successful or failed. The storage is tracked to ensure deduplication, and logs are generated whenever an event is moved to S3 storage.

# %%
# ------------------- Mock S3 Storage -------------------

storage = {
    "success": set(),  # Track event IDs for uniqueness
    "failed": set()
}
event_logs = {
    "success": {},
    "failed": {}
}

def move_to_s3(event, status="success"):
    """
    Simulates storing the event in S3 while ensuring deduplication with overwrite.
    Stores full event details in event_logs and tracks unique event IDs in storage.
    """
    event_id = event['eventId']

    # Store event ID in tracking set
    storage[status].add(event_id)

    # Overwrite event details in event_logs
    event_logs[status][event_id] = {
        "eventId": event['eventId'],
        "customerId": event['customerId'],
        "salesRepId": event['salesRepId'],
        "eventType": event['eventType'],
        "timestamp": event['timestamp'],
        "platform": event['platform'],
        "region": event['region'],
        "eventDetails": event['eventDetails'],
    }

    log_cloudwatch(f"Event {event_id} stored in {status} storage (S3)")

# %% [markdown]
# SageMaker Anomaly Detection This cell simulates anomaly detection that might be done with AWS SageMaker or another anomaly detection service. It checks for invalid data points (e.g., platform set to "Windows") and logs any anomalies detected.

# %%
# ------------------- SageMaker Anomaly Detection -------------------

def detect_anomalies(event):
    """
    Checks for any anomalies OR incorrectly processed data in the event data after successful calculation.
    Logs the anomaly detection in CloudWatch.
    Apply Anomaly detection algorithms to find. Below is just an example.
    """
    anomalies = []
    
    if event['platform'] == "Windows":  # Invalid platform
        anomalies.append("Anomaly: Invalid platform: Windows.")
    
    if anomalies:
        log_cloudwatch(f"Anomaly detected for event {event['eventId']}: {anomalies}")
        print(f"Event {event['eventId']} has anomalies: {anomalies}")
        return True  # Anomaly detected
    return False

# %% [markdown]
# Correcting Anomalies Simulates the correction of detected anomalies. If anomalies like an invalid platform are found in an event, this function modifies the event to correct the issue (e.g., changing platform to "iOS").

# %%
# ------------------- Already Calculated and flagged events Correction Function -------------------

def correct_anomaly(event):
    """
    Simulates correcting anomalies in a successfully calculated event.
    """
    log_cloudwatch(f"Correcting anomaly in event {event['eventId']}...")
    
    # Example: Fix invalid platform
    if event['platform'] == "Windows":
        event['platform'] = "iOS"  # Correcting platform anomaly
    
    return event

# %% [markdown]
# CloudWatch Anomaly Flagging This function simulates the process of flagging events with anomalies in CloudWatch. It also triggers the correction process by invoking the anomaly correction function defined in the previous cell.

# %%
# ------------------- CloudWatch Anomaly Flagging -------------------

def cloudwatch_flag_event_and_trigger_correction(event):
    """
    Logs a flagged anomaly event in CloudWatch and trigger correction lambda.
    """
    message = f"[CloudWatch Anomaly] Event {event['eventId']} flagged for anomalies"
    log_cloudwatch(message)
    # Try to correct the anomaly
    corrected_event = correct_anomaly(event)
    return corrected_event

# %% [markdown]
# Correction for Failed Events Simulates the correction of events that initially failed validation or processing. After correction, events are moved to the success storage (S3) to track the corrected events.

# %%
# ------------------- Already Calculated and flagged events Correction Function -------------------


def correction_for_failed(event):
    """
    Correction function for events that failed initially but were retried and then corrected.
    """
    log_cloudwatch(f"Correcting failed event {event['eventId']}...")
    
    # If a failed event is corrected, move to success storage
    move_to_s3(event, "success")
    return event

# %% [markdown]
# Retry Logic Simulates retrying the processing of events that failed during earlier stages (e.g., missing customerId or eventType). Events are retried a limited number of times before being permanently moved to the DLQ.

# %%
# ------------------- Retry Logic -------------------

def retry_event(event):
    retries = 0
    max_retries = 2
    fixed = False
    
    while retries < max_retries:
        log_cloudwatch(f"Retry attempt {retries + 1} for event {event['eventId']}...")

        if event['customerId'] is None or event['eventType'] is None:
            log_cloudwatch(f"Event {event['eventId']} cannot be fixed. Moving to failed storage.")
            move_to_s3(event, "failed")
            return False  # Critical failure

        if event['platform'] == "Windows":
            event['platform'] = "iOS"  # Fixable issue
            fixed = True
        
        if fixed:
            log_cloudwatch(f"Event {event['eventId']} fixed but retained in DLQ for review.")
            return True  # Stay in DLQ

        retries += 1

    log_cloudwatch(f"Event {event['eventId']} failed after {max_retries} retries. Moving to failed storage.")
    move_to_s3(event, "failed")
    return False

# %% [markdown]
# Event Calculation Simulates the event calculation step. After successful validation and anomaly checks, this function represents the final event processing and stores the event in S3 if it's successfully processed.

# %%
# ------------------- Event Calculation -------------------

def calculate_event(event):
    """
    Calculate the event if not already processed. Otherwise, skip.
    """
    calculated = False
    log_cloudwatch(f"Calculating event {event['eventId']}...")
    time.sleep(1)  # Simulate processing time
    calculated = True
    if calculated:
        move_to_s3(event, "success")
        log_cloudwatch(f"Event {event['eventId']} successfully calculated and stored.")
    return calculated

# %% [markdown]
# Retry After Correction Simulates retrying the calculation of an event after it has been corrected due to an anomaly detection. Events are retried multiple times before being permanently marked as failed or successfully recalculated.

# %%
def retry_after_correction(corrected_event):
    # Retry calculation up to 3 times
    max_retries = 3
    success = False
    for attempt in range(max_retries):
        log_cloudwatch(f"Recalculating event {corrected_event['eventId']} (Attempt {attempt + 1})...")

        if calculate_event(corrected_event):
            success = True
            break  # Exit loop if calculation succeeds

    if success:
        # Move to success storage if recalculation is successful
        move_to_s3(corrected_event, "success")
        log_cloudwatch(f"Event {corrected_event['eventId']} successfully recalculated and stored.")
    else:
        # If all retries fail, move to DLQ
        send_to_dlq(corrected_event, "retries failed")  # Send to DLQ
        log_cloudwatch(f"Event {corrected_event['eventId']} failed recalculations after {max_retries} attempts and sent to DLQ.")

# %% [markdown]
# Retry from DLQ This function processes events stored in the DLQ, attempting to fix and recalculate them. Events that can be fixed are processed and stored successfully, while those that continue to fail are kept in the DLQ.

# %%
# ------------------- Retry Logic -------------------
def retry_from_dlq():
    """
    Retries processing events from the DLQ.
    If an event is successfully processed, it moves to success storage.
    If anomalies are found, the event is corrected and recalculated.
    If it still fails after retries, it remains in DLQ.
    """
    global dlq  # Use the global DLQ
    
    # Iterate over a copy of DLQ to avoid modifying it while iterating
    for event_with_reason in dlq[:]:  # Iterate over a shallow copy to avoid modifying the list while iterating
        event = event_with_reason.copy()  # Copy event data without the reason for retry logic
        reason = event_with_reason.get("failure_reason", "Unknown")  # Retrieve the failure reason
     
        log_cloudwatch(f"\nRetrying event {event['eventId']} from DLQ. Reason: {reason}...")

        if retry_event(event):  # Attempt to fix the event before recalculation
            # Proceed with calculation
            calculated = calculate_event(event)
            if calculated:
                if detect_anomalies(event):
                    # Flag and correct the event
                    cloudwatch_flag_event(event)
                    corrected_event = correction_for_failed(event)

                    # Recalculate after correction
                    if calculate_event(corrected_event):
                        move_to_s3(corrected_event, "success")
                        log_cloudwatch(f"Event {corrected_event['eventId']} corrected and successfully recalculated.")
                        dlq.remove(event_tuple)  # Remove the event from DLQ after success
                    else:
                        log_cloudwatch(f"Event {event['eventId']} still failed after correction.")
                else:
                    # If no anomaly, move to success storage
                    move_to_s3(event, "success")
                    dlq.remove(event_tuple)  # Remove the event from DLQ
            else:
                log_cloudwatch(f"Event {event['eventId']} failed recalculation.")
        else:
            log_cloudwatch(f"Event {event['eventId']} could not be fixed. Keeping in DLQ.")

# %% [markdown]
# Full Event Processing This cell integrates the entire event processing flow. It generates a batch of events and processes each event through the various steps (validation, calculation, anomaly detection, etc.). The function handles retrying failed events and correcting anomalies, ensuring a smooth end-to-end pipeline simulation.

# %%
# ------------------- Full Event Processing -------------------

def process_batch(batch_size=100):
    events = [generate_customer_event(i) for i in range(batch_size)]
        
    for event in events:
        print(f"\nProcessing event {event['eventId']}...")
        print(event)

        # ------------------ Step 1: EventBridge Rule Check ------------------
        log_cloudwatch(f"Processing event {event['eventId']} through EventBridge validation...")
        if not eventbridge_rule_check(event):
            # If EventBridge Rule check fails, send to DLQ and stop further checks
            log_cloudwatch(f"Event {event['eventId']} failed EventBridge rule validation. Moving to DLQ.")
            send_to_dlq(event, "EventBridge Rule")
            continue  # Skip further processing for this event
        
        # ------------------ Step 2: Lambda Validation Check ------------------
        log_cloudwatch(f"Processing event {event['eventId']} through Lambda validation...")
        if not lambda_validation_check(event):
            # If Lambda validation fails, send to DLQ
            log_cloudwatch(f"Event {event['eventId']} failed Lambda validation. Moving to DLQ.")
            send_to_dlq(event, "Lambda Validation")
            continue  # Skip further processing for this event
        
        # Event is valid, proceed to calculation step
        calculated = calculate_event(event)
        if calculated:
            # After calculation, detect anomalies
            log_cloudwatch(f"Detecting anomalies for event {event['eventId']}...")
            if detect_anomalies(event):
                # Flag event in CloudWatch and trigger correction
                corrected_event = cloudwatch_flag_event_and_trigger_correction(event)
                if corrected_event:
                    log_cloudwatch(f"Event {event['eventId']} corrected after anomaly detection.")
                    retry_after_correction(event)
            else:
                print("No anomaly detected. Moving on.")
        else:
            # Move not calculated event to DLQ for retry
            send_to_dlq(event, "Not Calculated")
    
    retry_from_dlq()

# %%
process_batch(100)
# Out:
# Processing event 100000...
# {'eventId': 100000, 'customerId': 'C101', 'salesRepId': 'SR004', 'eventType': None, 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167516', 'platform': 'iOS', 'region': 'US'}
# [CloudWatch Log] Processing event 100000 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100000.
# [CloudWatch Log] Processing event 100000 through Lambda validation...
# [CloudWatch Log] Lambda validation failed: Missing or invalid 'eventType' in event 100000. Sending to DLQ
# [CloudWatch Log] Event 100000 failed Lambda validation. Moving to DLQ.
# [CloudWatch Log] Event 100000 sent to DLQ due to: Lambda Validation.
#
# Processing event 100001...
# {'eventId': 100001, 'customerId': 'C789', 'salesRepId': 'SR002', 'eventType': 'inquiry', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167523', 'platform': 'Android', 'region': 'US'}
# [CloudWatch Log] Processing event 100001 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100001.
# [CloudWatch Log] Processing event 100001 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100001.
# [CloudWatch Log] Calculating event 100001...
# [CloudWatch Log] Event 100001 stored in success storage (S3)
# [CloudWatch Log] Event 100001 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100001...
# No anomaly detected. Moving on.
#
# Processing event 100002...
# {'eventId': 100002, 'customerId': 'C101', 'salesRepId': 'SR003', 'eventType': None, 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167526', 'platform': 'Android', 'region': 'IN'}
# [CloudWatch Log] Processing event 100002 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100002.
# [CloudWatch Log] Processing event 100002 through Lambda validation...
# [CloudWatch Log] Lambda validation failed: Missing or invalid 'eventType' in event 100002. Sending to DLQ
# [CloudWatch Log] Event 100002 failed Lambda validation. Moving to DLQ.
# [CloudWatch Log] Event 100002 sent to DLQ due to: Lambda Validation.
#
# Processing event 100003...
# {'eventId': 100003, 'customerId': 'C456', 'salesRepId': 'SR001', 'eventType': 'ticket_resolved', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167529', 'platform': 'iOS', 'region': 'APAC'}
# [CloudWatch Log] Processing event 100003 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100003.
# [CloudWatch Log] Processing event 100003 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100003.
# [CloudWatch Log] Calculating event 100003...
# [CloudWatch Log] Event 100003 stored in success storage (S3)
# [CloudWatch Log] Event 100003 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100003...
# No anomaly detected. Moving on.
#
# Processing event 100004...
# {'eventId': 100004, 'customerId': 'C101', 'salesRepId': 'SR003', 'eventType': 'app_open', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167531', 'platform': 'Android', 'region': 'US'}
# [CloudWatch Log] Processing event 100004 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100004.
# [CloudWatch Log] Processing event 100004 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100004.
# [CloudWatch Log] Calculating event 100004...
# [CloudWatch Log] Event 100004 stored in success storage (S3)
# [CloudWatch Log] Event 100004 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100004...
# No anomaly detected. Moving on.
#
# Processing event 100005...
# {'eventId': 100005, 'customerId': None, 'salesRepId': 'SR001', 'eventType': 'ticket_created', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167533', 'platform': 'Android', 'region': 'APAC'}
# [CloudWatch Log] Processing event 100005 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100005.
# [CloudWatch Log] Processing event 100005 through Lambda validation...
# [CloudWatch Log] Lambda validation failed: Missing or invalid 'customerId' in event 100005. Sending to DLQ
# [CloudWatch Log] Event 100005 failed Lambda validation. Moving to DLQ.
# [CloudWatch Log] Event 100005 sent to DLQ due to: Lambda Validation.
#
# Processing event 100006...
# {'eventId': 100006, 'customerId': 'C101', 'salesRepId': 'SR004', 'eventType': 'meeting_scheduled', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167536', 'platform': 'iOS', 'region': 'APAC'}
# [CloudWatch Log] Processing event 100006 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100006.
# [CloudWatch Log] Processing event 100006 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100006.
# [CloudWatch Log] Calculating event 100006...
# [CloudWatch Log] Event 100006 stored in success storage (S3)
# [CloudWatch Log] Event 100006 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100006...
# No anomaly detected. Moving on.
#
# Processing event 100007...
# {'eventId': 100007, 'customerId': 'C101', 'salesRepId': 'SR001', 'eventType': 'app_open', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167538', 'platform': 'Android', 'region': 'IN'}
# [CloudWatch Log] Processing event 100007 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100007.
# [CloudWatch Log] Processing event 100007 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100007.
# [CloudWatch Log] Calculating event 100007...
# [CloudWatch Log] Event 100007 stored in success storage (S3)
# [CloudWatch Log] Event 100007 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100007...
# No anomaly detected. Moving on.
#
# Processing event 100008...
# {'eventId': 100008, 'customerId': 'C456', 'salesRepId': 'SR001', 'eventType': 'inquiry', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167541', 'platform': 'Windows', 'region': 'IN'}
# [CloudWatch Log] Processing event 100008 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100008.
# [CloudWatch Log] Processing event 100008 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100008.
# [CloudWatch Log] Calculating event 100008...
# [CloudWatch Log] Event 100008 stored in success storage (S3)
# [CloudWatch Log] Event 100008 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100008...
# [CloudWatch Log] Anomaly detected for event 100008: ['Anomaly: Invalid platform: Windows.']
# Event 100008 has anomalies: ['Anomaly: Invalid platform: Windows.']
# [CloudWatch Log] [CloudWatch Anomaly] Event 100008 flagged for anomalies
# [CloudWatch Log] Correcting anomaly in event 100008...
# [CloudWatch Log] Event 100008 corrected after anomaly detection.
# [CloudWatch Log] Recalculating event 100008 (Attempt 1)...
# [CloudWatch Log] Calculating event 100008...
# [CloudWatch Log] Event 100008 stored in success storage (S3)
# [CloudWatch Log] Event 100008 successfully calculated and stored.
# [CloudWatch Log] Event 100008 stored in success storage (S3)
# [CloudWatch Log] Event 100008 successfully recalculated and stored.
#
# Processing event 100009...
# {'eventId': 100009, 'customerId': 'C456', 'salesRepId': 'SR003', 'eventType': 'app_open', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167543', 'platform': 'iOS', 'region': 'APAC'}
# [CloudWatch Log] Processing event 100009 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100009.
# [CloudWatch Log] Processing event 100009 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100009.
# [CloudWatch Log] Calculating event 100009...
# [CloudWatch Log] Event 100009 stored in success storage (S3)
# [CloudWatch Log] Event 100009 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100009...
# No anomaly detected. Moving on.
#
# Processing event 100010...
# {'eventId': 100010, 'customerId': 'C456', 'salesRepId': 'SR002', 'eventType': 'ticket_resolved', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167545', 'platform': 'Android', 'region': 'APAC'}
# [CloudWatch Log] Processing event 100010 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100010.
# [CloudWatch Log] Processing event 100010 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100010.
# [CloudWatch Log] Calculating event 100010...
# [CloudWatch Log] Event 100010 stored in success storage (S3)
# [CloudWatch Log] Event 100010 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100010...
# No anomaly detected. Moving on.
#
# Processing event 100011...
# {'eventId': 100011, 'customerId': 'C112', 'salesRepId': 'SR004', 'eventType': 'ticket_resolved', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167548', 'platform': 'iOS', 'region': 'US'}
# [CloudWatch Log] Processing event 100011 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100011.
# [CloudWatch Log] Processing event 100011 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100011.
# [CloudWatch Log] Calculating event 100011...
# [CloudWatch Log] Event 100011 stored in success storage (S3)
# [CloudWatch Log] Event 100011 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100011...
# No anomaly detected. Moving on.
#
# Processing event 100012...
# {'eventId': 100012, 'customerId': 'C123', 'salesRepId': 'SR004', 'eventType': 'ticket_created', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167550', 'platform': 'Android', 'region': 'EU'}
# [CloudWatch Log] Processing event 100012 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100012.
# [CloudWatch Log] Processing event 100012 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100012.
# [CloudWatch Log] Calculating event 100012...
# [CloudWatch Log] Event 100012 stored in success storage (S3)
# [CloudWatch Log] Event 100012 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100012...
# No anomaly detected. Moving on.
#
# Processing event 100013...
# {'eventId': 100013, 'customerId': 'C456', 'salesRepId': 'SR002', 'eventType': 'inquiry', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167553', 'platform': 'iOS', 'region': 'EU'}
# [CloudWatch Log] Processing event 100013 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100013.
# [CloudWatch Log] Processing event 100013 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100013.
# [CloudWatch Log] Calculating event 100013...
# [CloudWatch Log] Event 100013 stored in success storage (S3)
# [CloudWatch Log] Event 100013 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100013...
# No anomaly detected. Moving on.
#
# Processing event 100014...
# {'eventId': 100014, 'customerId': 'C789', 'salesRepId': 'SR002', 'eventType': 'inquiry', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167555', 'platform': 'Windows', 'region': 'EU'}
# [CloudWatch Log] Processing event 100014 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100014.
# [CloudWatch Log] Processing event 100014 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100014.
# [CloudWatch Log] Calculating event 100014...
# [CloudWatch Log] Event 100014 stored in success storage (S3)
# [CloudWatch Log] Event 100014 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100014...
# [CloudWatch Log] Anomaly detected for event 100014: ['Anomaly: Invalid platform: Windows.']
# Event 100014 has anomalies: ['Anomaly: Invalid platform: Windows.']
# [CloudWatch Log] [CloudWatch Anomaly] Event 100014 flagged for anomalies
# [CloudWatch Log] Correcting anomaly in event 100014...
# [CloudWatch Log] Event 100014 corrected after anomaly detection.
# [CloudWatch Log] Recalculating event 100014 (Attempt 1)...
# [CloudWatch Log] Calculating event 100014...
# [CloudWatch Log] Event 100014 stored in success storage (S3)
# [CloudWatch Log] Event 100014 successfully calculated and stored.
# [CloudWatch Log] Event 100014 stored in success storage (S3)
# [CloudWatch Log] Event 100014 successfully recalculated and stored.
#
# Processing event 100015...
# {'eventId': 100015, 'customerId': 'C456', 'salesRepId': 'SR004', 'eventType': 'inquiry', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167557', 'platform': 'Windows', 'region': 'US'}
# [CloudWatch Log] Processing event 100015 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100015.
# [CloudWatch Log] Processing event 100015 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100015.
# [CloudWatch Log] Calculating event 100015...
# [CloudWatch Log] Event 100015 stored in success storage (S3)
# [CloudWatch Log] Event 100015 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100015...
# [CloudWatch Log] Anomaly detected for event 100015: ['Anomaly: Invalid platform: Windows.']
# Event 100015 has anomalies: ['Anomaly: Invalid platform: Windows.']
# [CloudWatch Log] [CloudWatch Anomaly] Event 100015 flagged for anomalies
# [CloudWatch Log] Correcting anomaly in event 100015...
# [CloudWatch Log] Event 100015 corrected after anomaly detection.
# [CloudWatch Log] Recalculating event 100015 (Attempt 1)...
# [CloudWatch Log] Calculating event 100015...
# [CloudWatch Log] Event 100015 stored in success storage (S3)
# [CloudWatch Log] Event 100015 successfully calculated and stored.
# [CloudWatch Log] Event 100015 stored in success storage (S3)
# [CloudWatch Log] Event 100015 successfully recalculated and stored.
#
# Processing event 100016...
# {'eventId': 100016, 'customerId': 'C123', 'salesRepId': 'SR004', 'eventType': 'inquiry', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167559', 'platform': 'Android', 'region': 'APAC'}
# [CloudWatch Log] Processing event 100016 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100016.
# [CloudWatch Log] Processing event 100016 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100016.
# [CloudWatch Log] Calculating event 100016...
# [CloudWatch Log] Event 100016 stored in success storage (S3)
# [CloudWatch Log] Event 100016 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100016...
# No anomaly detected. Moving on.
#
# Processing event 100017...
# {'eventId': 100017, 'customerId': 'C123', 'salesRepId': 'SR004', 'eventType': 'inquiry', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167561', 'platform': 'Android', 'region': 'EU'}
# [CloudWatch Log] Processing event 100017 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100017.
# [CloudWatch Log] Processing event 100017 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100017.
# [CloudWatch Log] Calculating event 100017...
# [CloudWatch Log] Event 100017 stored in success storage (S3)
# [CloudWatch Log] Event 100017 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100017...
# No anomaly detected. Moving on.
#
# Processing event 100018...
# {'eventId': 100018, 'customerId': 'C123', 'salesRepId': 'SR001', 'eventType': 'meeting_scheduled', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167564', 'platform': 'Android', 'region': 'EU'}
# [CloudWatch Log] Processing event 100018 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100018.
# [CloudWatch Log] Processing event 100018 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100018.
# [CloudWatch Log] Calculating event 100018...
# [CloudWatch Log] Event 100018 stored in success storage (S3)
# [CloudWatch Log] Event 100018 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100018...
# No anomaly detected. Moving on.
#
# Processing event 100019...
# {'eventId': 100019, 'customerId': 'C789', 'salesRepId': 'SR004', 'eventType': 'ticket_resolved', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167566', 'platform': 'iOS', 'region': 'EU'}
# [CloudWatch Log] Processing event 100019 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100019.
# [CloudWatch Log] Processing event 100019 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100019.
# [CloudWatch Log] Calculating event 100019...
# [CloudWatch Log] Event 100019 stored in success storage (S3)
# [CloudWatch Log] Event 100019 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100019...
# No anomaly detected. Moving on.
#
# Processing event 100020...
# {'eventId': 100020, 'customerId': 'C101', 'salesRepId': 'SR003', 'eventType': 'app_open', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167569', 'platform': 'iOS', 'region': 'IN'}
# [CloudWatch Log] Processing event 100020 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100020.
# [CloudWatch Log] Processing event 100020 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100020.
# [CloudWatch Log] Calculating event 100020...
# [CloudWatch Log] Event 100020 stored in success storage (S3)
# [CloudWatch Log] Event 100020 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100020...
# No anomaly detected. Moving on.
#
# Processing event 100021...
# {'eventId': 100021, 'customerId': 'C112', 'salesRepId': 'SR003', 'eventType': 'app_open', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167571', 'platform': 'Android', 'region': 'APAC'}
# [CloudWatch Log] Processing event 100021 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100021.
# [CloudWatch Log] Processing event 100021 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100021.
# [CloudWatch Log] Calculating event 100021...
# [CloudWatch Log] Event 100021 stored in success storage (S3)
# [CloudWatch Log] Event 100021 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100021...
# No anomaly detected. Moving on.
#
# Processing event 100022...
# {'eventId': 100022, 'customerId': None, 'salesRepId': 'SR001', 'eventType': 'meeting_scheduled', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167574', 'platform': 'iOS', 'region': 'IN'}
# [CloudWatch Log] Processing event 100022 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100022.
# [CloudWatch Log] Processing event 100022 through Lambda validation...
# [CloudWatch Log] Lambda validation failed: Missing or invalid 'customerId' in event 100022. Sending to DLQ
# [CloudWatch Log] Event 100022 failed Lambda validation. Moving to DLQ.
# [CloudWatch Log] Event 100022 sent to DLQ due to: Lambda Validation.
#
# Processing event 100023...
# {'eventId': 100023, 'customerId': 'C101', 'salesRepId': 'SR002', 'eventType': 'inquiry', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167576', 'platform': 'iOS', 'region': 'EU'}
# [CloudWatch Log] Processing event 100023 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100023.
# [CloudWatch Log] Processing event 100023 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100023.
# [CloudWatch Log] Calculating event 100023...
# [CloudWatch Log] Event 100023 stored in success storage (S3)
# [CloudWatch Log] Event 100023 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100023...
# No anomaly detected. Moving on.
#
# Processing event 100024...
# {'eventId': 100024, 'customerId': 'C123', 'salesRepId': 'SR002', 'eventType': 'inquiry', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167578', 'platform': 'Android', 'region': 'EU'}
# [CloudWatch Log] Processing event 100024 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100024.
# [CloudWatch Log] Processing event 100024 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100024.
# [CloudWatch Log] Calculating event 100024...
# [CloudWatch Log] Event 100024 stored in success storage (S3)
# [CloudWatch Log] Event 100024 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100024...
# No anomaly detected. Moving on.
#
# Processing event 100025...
# {'eventId': 100025, 'customerId': 'C456', 'salesRepId': 'SR004', 'eventType': 'app_open', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167581', 'platform': 'Android', 'region': 'US'}
# [CloudWatch Log] Processing event 100025 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100025.
# [CloudWatch Log] Processing event 100025 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100025.
# [CloudWatch Log] Calculating event 100025...
# [CloudWatch Log] Event 100025 stored in success storage (S3)
# [CloudWatch Log] Event 100025 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100025...
# No anomaly detected. Moving on.
#
# Processing event 100026...
# {'eventId': 100026, 'customerId': 'C789', 'salesRepId': 'SR001', 'eventType': 'ticket_resolved', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167583', 'platform': 'iOS', 'region': 'EU'}
# [CloudWatch Log] Processing event 100026 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100026.
# [CloudWatch Log] Processing event 100026 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100026.
# [CloudWatch Log] Calculating event 100026...
# [CloudWatch Log] Event 100026 stored in success storage (S3)
# [CloudWatch Log] Event 100026 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100026...
# No anomaly detected. Moving on.
#
# Processing event 100027...
# {'eventId': 100027, 'customerId': 'C123', 'salesRepId': 'SR004', 'eventType': 'call_logged', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167585', 'platform': 'iOS', 'region': 'EU'}
# [CloudWatch Log] Processing event 100027 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100027.
# [CloudWatch Log] Processing event 100027 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100027.
# [CloudWatch Log] Calculating event 100027...
# [CloudWatch Log] Event 100027 stored in success storage (S3)
# [CloudWatch Log] Event 100027 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100027...
# No anomaly detected. Moving on.
#
# Processing event 100028...
# {'eventId': 100028, 'customerId': 'C112', 'salesRepId': 'SR003', 'eventType': 'app_open', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167588', 'platform': 'iOS', 'region': 'EU'}
# [CloudWatch Log] Processing event 100028 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100028.
# [CloudWatch Log] Processing event 100028 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100028.
# [CloudWatch Log] Calculating event 100028...
# [CloudWatch Log] Event 100028 stored in success storage (S3)
# [CloudWatch Log] Event 100028 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100028...
# No anomaly detected. Moving on.
#
# Processing event 100029...
# {'eventId': 100029, 'customerId': 'C789', 'salesRepId': 'SR001', 'eventType': 'ticket_resolved', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167590', 'platform': 'iOS', 'region': 'IN'}
# [CloudWatch Log] Processing event 100029 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100029.
# [CloudWatch Log] Processing event 100029 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100029.
# [CloudWatch Log] Calculating event 100029...
# [CloudWatch Log] Event 100029 stored in success storage (S3)
# [CloudWatch Log] Event 100029 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100029...
# No anomaly detected. Moving on.
#
# Processing event 100030...
# {'eventId': 100030, 'customerId': 'C101', 'salesRepId': 'SR001', 'eventType': 'call_logged', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167593', 'platform': 'iOS', 'region': 'IN'}
# [CloudWatch Log] Processing event 100030 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100030.
# [CloudWatch Log] Processing event 100030 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100030.
# [CloudWatch Log] Calculating event 100030...
# [CloudWatch Log] Event 100030 stored in success storage (S3)
# [CloudWatch Log] Event 100030 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100030...
# No anomaly detected. Moving on.
#
# Processing event 100031...
# {'eventId': 100031, 'customerId': 'C123', 'salesRepId': 'SR001', 'eventType': 'ticket_created', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167595', 'platform': 'iOS', 'region': 'EU'}
# [CloudWatch Log] Processing event 100031 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100031.
# [CloudWatch Log] Processing event 100031 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100031.
# [CloudWatch Log] Calculating event 100031...
# [CloudWatch Log] Event 100031 stored in success storage (S3)
# [CloudWatch Log] Event 100031 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100031...
# No anomaly detected. Moving on.
#
# Processing event 100032...
# {'eventId': 100032, 'customerId': 'C101', 'salesRepId': 'SR001', 'eventType': 'call_logged', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167597', 'platform': 'Android', 'region': 'APAC'}
# [CloudWatch Log] Processing event 100032 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100032.
# [CloudWatch Log] Processing event 100032 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100032.
# [CloudWatch Log] Calculating event 100032...
# [CloudWatch Log] Event 100032 stored in success storage (S3)
# [CloudWatch Log] Event 100032 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100032...
# No anomaly detected. Moving on.
#
# Processing event 100033...
# {'eventId': 100033, 'customerId': 'C789', 'salesRepId': 'SR002', 'eventType': 'call_logged', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167600', 'platform': 'Windows', 'region': 'EU'}
# [CloudWatch Log] Processing event 100033 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100033.
# [CloudWatch Log] Processing event 100033 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100033.
# [CloudWatch Log] Calculating event 100033...
# [CloudWatch Log] Event 100033 stored in success storage (S3)
# [CloudWatch Log] Event 100033 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100033...
# [CloudWatch Log] Anomaly detected for event 100033: ['Anomaly: Invalid platform: Windows.']
# Event 100033 has anomalies: ['Anomaly: Invalid platform: Windows.']
# [CloudWatch Log] [CloudWatch Anomaly] Event 100033 flagged for anomalies
# [CloudWatch Log] Correcting anomaly in event 100033...
# [CloudWatch Log] Event 100033 corrected after anomaly detection.
# [CloudWatch Log] Recalculating event 100033 (Attempt 1)...
# [CloudWatch Log] Calculating event 100033...
# [CloudWatch Log] Event 100033 stored in success storage (S3)
# [CloudWatch Log] Event 100033 successfully calculated and stored.
# [CloudWatch Log] Event 100033 stored in success storage (S3)
# [CloudWatch Log] Event 100033 successfully recalculated and stored.
#
# Processing event 100034...
# {'eventId': 100034, 'customerId': 'C789', 'salesRepId': 'SR001', 'eventType': 'ticket_resolved', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167602', 'platform': 'iOS', 'region': 'US'}
# [CloudWatch Log] Processing event 100034 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100034.
# [CloudWatch Log] Processing event 100034 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100034.
# [CloudWatch Log] Calculating event 100034...
# [CloudWatch Log] Event 100034 stored in success storage (S3)
# [CloudWatch Log] Event 100034 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100034...
# No anomaly detected. Moving on.
#
# Processing event 100035...
# {'eventId': 100035, 'customerId': 'C456', 'salesRepId': 'SR002', 'eventType': 'ticket_resolved', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167604', 'platform': 'Android', 'region': 'US'}
# [CloudWatch Log] Processing event 100035 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100035.
# [CloudWatch Log] Processing event 100035 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100035.
# [CloudWatch Log] Calculating event 100035...
# [CloudWatch Log] Event 100035 stored in success storage (S3)
# [CloudWatch Log] Event 100035 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100035...
# No anomaly detected. Moving on.
#
# Processing event 100036...
# {'eventId': 100036, 'customerId': 'C123', 'salesRepId': 'SR003', 'eventType': 'meeting_scheduled', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167607', 'platform': 'iOS', 'region': 'US'}
# [CloudWatch Log] Processing event 100036 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100036.
# [CloudWatch Log] Processing event 100036 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100036.
# [CloudWatch Log] Calculating event 100036...
# [CloudWatch Log] Event 100036 stored in success storage (S3)
# [CloudWatch Log] Event 100036 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100036...
# No anomaly detected. Moving on.
#
# Processing event 100037...
# {'eventId': 100037, 'customerId': 'C456', 'salesRepId': 'SR004', 'eventType': 'inquiry', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167609', 'platform': 'Android', 'region': 'EU'}
# [CloudWatch Log] Processing event 100037 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100037.
# [CloudWatch Log] Processing event 100037 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100037.
# [CloudWatch Log] Calculating event 100037...
# [CloudWatch Log] Event 100037 stored in success storage (S3)
# [CloudWatch Log] Event 100037 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100037...
# No anomaly detected. Moving on.
#
# Processing event 100038...
# {'eventId': 100038, 'customerId': 'C123', 'salesRepId': 'SR001', 'eventType': 'inquiry', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167612', 'platform': 'Windows', 'region': 'APAC'}
# [CloudWatch Log] Processing event 100038 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100038.
# [CloudWatch Log] Processing event 100038 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100038.
# [CloudWatch Log] Calculating event 100038...
# [CloudWatch Log] Event 100038 stored in success storage (S3)
# [CloudWatch Log] Event 100038 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100038...
# [CloudWatch Log] Anomaly detected for event 100038: ['Anomaly: Invalid platform: Windows.']
# Event 100038 has anomalies: ['Anomaly: Invalid platform: Windows.']
# [CloudWatch Log] [CloudWatch Anomaly] Event 100038 flagged for anomalies
# [CloudWatch Log] Correcting anomaly in event 100038...
# [CloudWatch Log] Event 100038 corrected after anomaly detection.
# [CloudWatch Log] Recalculating event 100038 (Attempt 1)...
# [CloudWatch Log] Calculating event 100038...
# [CloudWatch Log] Event 100038 stored in success storage (S3)
# [CloudWatch Log] Event 100038 successfully calculated and stored.
# [CloudWatch Log] Event 100038 stored in success storage (S3)
# [CloudWatch Log] Event 100038 successfully recalculated and stored.
#
# Processing event 100039...
# {'eventId': 100039, 'customerId': 'C101', 'salesRepId': 'SR001', 'eventType': 'inquiry', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167614', 'platform': 'Windows', 'region': 'IN'}
# [CloudWatch Log] Processing event 100039 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100039.
# [CloudWatch Log] Processing event 100039 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100039.
# [CloudWatch Log] Calculating event 100039...
# [CloudWatch Log] Event 100039 stored in success storage (S3)
# [CloudWatch Log] Event 100039 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100039...
# [CloudWatch Log] Anomaly detected for event 100039: ['Anomaly: Invalid platform: Windows.']
# Event 100039 has anomalies: ['Anomaly: Invalid platform: Windows.']
# [CloudWatch Log] [CloudWatch Anomaly] Event 100039 flagged for anomalies
# [CloudWatch Log] Correcting anomaly in event 100039...
# [CloudWatch Log] Event 100039 corrected after anomaly detection.
# [CloudWatch Log] Recalculating event 100039 (Attempt 1)...
# [CloudWatch Log] Calculating event 100039...
# [CloudWatch Log] Event 100039 stored in success storage (S3)
# [CloudWatch Log] Event 100039 successfully calculated and stored.
# [CloudWatch Log] Event 100039 stored in success storage (S3)
# [CloudWatch Log] Event 100039 successfully recalculated and stored.
#
# Processing event 100040...
# {'eventId': 100040, 'customerId': None, 'salesRepId': 'SR003', 'eventType': 'app_open', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167616', 'platform': 'Android', 'region': 'IN'}
# [CloudWatch Log] Processing event 100040 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100040.
# [CloudWatch Log] Processing event 100040 through Lambda validation...
# [CloudWatch Log] Lambda validation failed: Missing or invalid 'customerId' in event 100040. Sending to DLQ
# [CloudWatch Log] Event 100040 failed Lambda validation. Moving to DLQ.
# [CloudWatch Log] Event 100040 sent to DLQ due to: Lambda Validation.
#
# Processing event 100041...
# {'eventId': 100041, 'customerId': 'C112', 'salesRepId': 'SR003', 'eventType': 'call_logged', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167619', 'platform': 'Windows', 'region': 'US'}
# [CloudWatch Log] Processing event 100041 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100041.
# [CloudWatch Log] Processing event 100041 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100041.
# [CloudWatch Log] Calculating event 100041...
# [CloudWatch Log] Event 100041 stored in success storage (S3)
# [CloudWatch Log] Event 100041 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100041...
# [CloudWatch Log] Anomaly detected for event 100041: ['Anomaly: Invalid platform: Windows.']
# Event 100041 has anomalies: ['Anomaly: Invalid platform: Windows.']
# [CloudWatch Log] [CloudWatch Anomaly] Event 100041 flagged for anomalies
# [CloudWatch Log] Correcting anomaly in event 100041...
# [CloudWatch Log] Event 100041 corrected after anomaly detection.
# [CloudWatch Log] Recalculating event 100041 (Attempt 1)...
# [CloudWatch Log] Calculating event 100041...
# [CloudWatch Log] Event 100041 stored in success storage (S3)
# [CloudWatch Log] Event 100041 successfully calculated and stored.
# [CloudWatch Log] Event 100041 stored in success storage (S3)
# [CloudWatch Log] Event 100041 successfully recalculated and stored.
#
# Processing event 100042...
# {'eventId': 100042, 'customerId': 'C789', 'salesRepId': 'SR001', 'eventType': 'ticket_resolved', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167622', 'platform': 'Android', 'region': 'APAC'}
# [CloudWatch Log] Processing event 100042 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100042.
# [CloudWatch Log] Processing event 100042 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100042.
# [CloudWatch Log] Calculating event 100042...
# [CloudWatch Log] Event 100042 stored in success storage (S3)
# [CloudWatch Log] Event 100042 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100042...
# No anomaly detected. Moving on.
#
# Processing event 100043...
# {'eventId': 100043, 'customerId': 'C456', 'salesRepId': 'SR004', 'eventType': 'inquiry', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167624', 'platform': 'Android', 'region': 'IN'}
# [CloudWatch Log] Processing event 100043 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100043.
# [CloudWatch Log] Processing event 100043 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100043.
# [CloudWatch Log] Calculating event 100043...
# [CloudWatch Log] Event 100043 stored in success storage (S3)
# [CloudWatch Log] Event 100043 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100043...
# No anomaly detected. Moving on.
#
# Processing event 100044...
# {'eventId': 100044, 'customerId': 'C456', 'salesRepId': 'SR002', 'eventType': 'call_logged', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167626', 'platform': 'iOS', 'region': 'IN'}
# [CloudWatch Log] Processing event 100044 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100044.
# [CloudWatch Log] Processing event 100044 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100044.
# [CloudWatch Log] Calculating event 100044...
# [CloudWatch Log] Event 100044 stored in success storage (S3)
# [CloudWatch Log] Event 100044 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100044...
# No anomaly detected. Moving on.
#
# Processing event 100045...
# {'eventId': 100045, 'customerId': 'C456', 'salesRepId': 'SR004', 'eventType': 'app_open', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167631', 'platform': 'Android', 'region': 'US'}
# [CloudWatch Log] Processing event 100045 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100045.
# [CloudWatch Log] Processing event 100045 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100045.
# [CloudWatch Log] Calculating event 100045...
# [CloudWatch Log] Event 100045 stored in success storage (S3)
# [CloudWatch Log] Event 100045 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100045...
# No anomaly detected. Moving on.
#
# Processing event 100046...
# {'eventId': 100046, 'customerId': 'C456', 'salesRepId': 'SR001', 'eventType': 'meeting_scheduled', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167633', 'platform': 'iOS', 'region': 'US'}
# [CloudWatch Log] Processing event 100046 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100046.
# [CloudWatch Log] Processing event 100046 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100046.
# [CloudWatch Log] Calculating event 100046...
# [CloudWatch Log] Event 100046 stored in success storage (S3)
# [CloudWatch Log] Event 100046 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100046...
# No anomaly detected. Moving on.
#
# Processing event 100047...
# {'eventId': 100047, 'customerId': 'C789', 'salesRepId': 'SR004', 'eventType': 'inquiry', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167635', 'platform': 'Android', 'region': 'APAC'}
# [CloudWatch Log] Processing event 100047 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100047.
# [CloudWatch Log] Processing event 100047 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100047.
# [CloudWatch Log] Calculating event 100047...
# [CloudWatch Log] Event 100047 stored in success storage (S3)
# [CloudWatch Log] Event 100047 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100047...
# No anomaly detected. Moving on.
#
# Processing event 100048...
# {'eventId': 100048, 'customerId': 'C789', 'salesRepId': 'SR003', 'eventType': None, 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167638', 'platform': 'Android', 'region': 'US'}
# [CloudWatch Log] Processing event 100048 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100048.
# [CloudWatch Log] Processing event 100048 through Lambda validation...
# [CloudWatch Log] Lambda validation failed: Missing or invalid 'eventType' in event 100048. Sending to DLQ
# [CloudWatch Log] Event 100048 failed Lambda validation. Moving to DLQ.
# [CloudWatch Log] Event 100048 sent to DLQ due to: Lambda Validation.
#
# Processing event 100049...
# {'eventId': 100049, 'customerId': 'C112', 'salesRepId': 'SR001', 'eventType': 'ticket_resolved', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167640', 'platform': 'Android', 'region': 'EU'}
# [CloudWatch Log] Processing event 100049 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100049.
# [CloudWatch Log] Processing event 100049 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100049.
# [CloudWatch Log] Calculating event 100049...
# [CloudWatch Log] Event 100049 stored in success storage (S3)
# [CloudWatch Log] Event 100049 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100049...
# No anomaly detected. Moving on.
#
# Processing event 100050...
# {'eventId': 100050, 'customerId': 'C456', 'salesRepId': 'SR003', 'eventType': 'inquiry', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167642', 'platform': 'iOS', 'region': 'IN'}
# [CloudWatch Log] Processing event 100050 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100050.
# [CloudWatch Log] Processing event 100050 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100050.
# [CloudWatch Log] Calculating event 100050...
# [CloudWatch Log] Event 100050 stored in success storage (S3)
# [CloudWatch Log] Event 100050 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100050...
# No anomaly detected. Moving on.
#
# Processing event 100051...
# {'eventId': 100051, 'customerId': 'C123', 'salesRepId': 'SR003', 'eventType': 'ticket_created', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167644', 'platform': 'Android', 'region': 'APAC'}
# [CloudWatch Log] Processing event 100051 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100051.
# [CloudWatch Log] Processing event 100051 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100051.
# [CloudWatch Log] Calculating event 100051...
# [CloudWatch Log] Event 100051 stored in success storage (S3)
# [CloudWatch Log] Event 100051 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100051...
# No anomaly detected. Moving on.
#
# Processing event 100052...
# {'eventId': 100052, 'customerId': 'C456', 'salesRepId': 'SR003', 'eventType': 'ticket_resolved', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167647', 'platform': 'iOS', 'region': 'US'}
# [CloudWatch Log] Processing event 100052 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100052.
# [CloudWatch Log] Processing event 100052 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100052.
# [CloudWatch Log] Calculating event 100052...
# [CloudWatch Log] Event 100052 stored in success storage (S3)
# [CloudWatch Log] Event 100052 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100052...
# No anomaly detected. Moving on.
#
# Processing event 100053...
# {'eventId': 100053, 'customerId': 'C456', 'salesRepId': 'SR002', 'eventType': 'ticket_resolved', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167649', 'platform': 'Android', 'region': 'IN'}
# [CloudWatch Log] Processing event 100053 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100053.
# [CloudWatch Log] Processing event 100053 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100053.
# [CloudWatch Log] Calculating event 100053...
# [CloudWatch Log] Event 100053 stored in success storage (S3)
# [CloudWatch Log] Event 100053 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100053...
# No anomaly detected. Moving on.
#
# Processing event 100054...
# {'eventId': 100054, 'customerId': 'C123', 'salesRepId': 'SR003', 'eventType': 'meeting_scheduled', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167651', 'platform': 'iOS', 'region': 'EU'}
# [CloudWatch Log] Processing event 100054 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100054.
# [CloudWatch Log] Processing event 100054 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100054.
# [CloudWatch Log] Calculating event 100054...
# [CloudWatch Log] Event 100054 stored in success storage (S3)
# [CloudWatch Log] Event 100054 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100054...
# No anomaly detected. Moving on.
#
# Processing event 100055...
# {'eventId': 100055, 'customerId': 'C789', 'salesRepId': 'SR001', 'eventType': 'ticket_resolved', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167653', 'platform': 'iOS', 'region': 'EU'}
# [CloudWatch Log] Processing event 100055 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100055.
# [CloudWatch Log] Processing event 100055 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100055.
# [CloudWatch Log] Calculating event 100055...
# [CloudWatch Log] Event 100055 stored in success storage (S3)
# [CloudWatch Log] Event 100055 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100055...
# ...
# [CloudWatch Log] Event 100085 failed Lambda validation. Moving to DLQ.
# [CloudWatch Log] Event 100085 sent to DLQ due to: Lambda Validation.
#
# Processing event 100086...
# {'eventId': 100086, 'customerId': None, 'salesRepId': 'SR001', 'eventType': 'app_open', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167781', 'platform': 'iOS', 'region': 'APAC'}
# [CloudWatch Log] Processing event 100086 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100086.
# [CloudWatch Log] Processing event 100086 through Lambda validation...
# [CloudWatch Log] Lambda validation failed: Missing or invalid 'customerId' in event 100086. Sending to DLQ
# [CloudWatch Log] Event 100086 failed Lambda validation. Moving to DLQ.
# [CloudWatch Log] Event 100086 sent to DLQ due to: Lambda Validation.
#
# Processing event 100087...
# {'eventId': 100087, 'customerId': 'C456', 'salesRepId': 'SR003', 'eventType': None, 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167783', 'platform': 'iOS', 'region': 'IN'}
# [CloudWatch Log] Processing event 100087 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100087.
# [CloudWatch Log] Processing event 100087 through Lambda validation...
# [CloudWatch Log] Lambda validation failed: Missing or invalid 'eventType' in event 100087. Sending to DLQ
# [CloudWatch Log] Event 100087 failed Lambda validation. Moving to DLQ.
# [CloudWatch Log] Event 100087 sent to DLQ due to: Lambda Validation.
#
# Processing event 100088...
# {'eventId': 100088, 'customerId': 'C112', 'salesRepId': 'SR004', 'eventType': 'meeting_scheduled', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167785', 'platform': 'Android', 'region': 'US'}
# [CloudWatch Log] Processing event 100088 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100088.
# [CloudWatch Log] Processing event 100088 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100088.
# [CloudWatch Log] Calculating event 100088...
# [CloudWatch Log] Event 100088 stored in success storage (S3)
# [CloudWatch Log] Event 100088 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100088...
# No anomaly detected. Moving on.
#
# Processing event 100089...
# {'eventId': 100089, 'customerId': 'C789', 'salesRepId': 'SR003', 'eventType': 'ticket_resolved', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167788', 'platform': 'iOS', 'region': 'US'}
# [CloudWatch Log] Processing event 100089 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100089.
# [CloudWatch Log] Processing event 100089 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100089.
# [CloudWatch Log] Calculating event 100089...
# [CloudWatch Log] Event 100089 stored in success storage (S3)
# [CloudWatch Log] Event 100089 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100089...
# No anomaly detected. Moving on.
#
# Processing event 100090...
# {'eventId': 100090, 'customerId': 'C112', 'salesRepId': 'SR004', 'eventType': 'ticket_resolved', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167790', 'platform': 'iOS', 'region': 'APAC'}
# [CloudWatch Log] Processing event 100090 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100090.
# [CloudWatch Log] Processing event 100090 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100090.
# [CloudWatch Log] Calculating event 100090...
# [CloudWatch Log] Event 100090 stored in success storage (S3)
# [CloudWatch Log] Event 100090 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100090...
# No anomaly detected. Moving on.
#
# Processing event 100091...
# {'eventId': 100091, 'customerId': 'C456', 'salesRepId': 'SR003', 'eventType': 'inquiry', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167792', 'platform': 'Windows', 'region': 'US'}
# [CloudWatch Log] Processing event 100091 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100091.
# [CloudWatch Log] Processing event 100091 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100091.
# [CloudWatch Log] Calculating event 100091...
# [CloudWatch Log] Event 100091 stored in success storage (S3)
# [CloudWatch Log] Event 100091 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100091...
# [CloudWatch Log] Anomaly detected for event 100091: ['Anomaly: Invalid platform: Windows.']
# Event 100091 has anomalies: ['Anomaly: Invalid platform: Windows.']
# [CloudWatch Log] [CloudWatch Anomaly] Event 100091 flagged for anomalies
# [CloudWatch Log] Correcting anomaly in event 100091...
# [CloudWatch Log] Event 100091 corrected after anomaly detection.
# [CloudWatch Log] Recalculating event 100091 (Attempt 1)...
# [CloudWatch Log] Calculating event 100091...
# [CloudWatch Log] Event 100091 stored in success storage (S3)
# [CloudWatch Log] Event 100091 successfully calculated and stored.
# [CloudWatch Log] Event 100091 stored in success storage (S3)
# [CloudWatch Log] Event 100091 successfully recalculated and stored.
#
# Processing event 100092...
# {'eventId': 100092, 'customerId': 'C456', 'salesRepId': 'SR004', 'eventType': 'ticket_resolved', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167794', 'platform': 'iOS', 'region': 'APAC'}
# [CloudWatch Log] Processing event 100092 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100092.
# [CloudWatch Log] Processing event 100092 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100092.
# [CloudWatch Log] Calculating event 100092...
# [CloudWatch Log] Event 100092 stored in success storage (S3)
# [CloudWatch Log] Event 100092 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100092...
# No anomaly detected. Moving on.
#
# Processing event 100093...
# {'eventId': 100093, 'customerId': None, 'salesRepId': 'SR004', 'eventType': 'meeting_scheduled', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167797', 'platform': 'Android', 'region': 'US'}
# [CloudWatch Log] Processing event 100093 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100093.
# [CloudWatch Log] Processing event 100093 through Lambda validation...
# [CloudWatch Log] Lambda validation failed: Missing or invalid 'customerId' in event 100093. Sending to DLQ
# [CloudWatch Log] Event 100093 failed Lambda validation. Moving to DLQ.
# [CloudWatch Log] Event 100093 sent to DLQ due to: Lambda Validation.
#
# Processing event 100094...
# {'eventId': 100094, 'customerId': 'C112', 'salesRepId': 'SR003', 'eventType': 'meeting_scheduled', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167799', 'platform': 'Android', 'region': 'APAC'}
# [CloudWatch Log] Processing event 100094 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100094.
# [CloudWatch Log] Processing event 100094 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100094.
# [CloudWatch Log] Calculating event 100094...
# [CloudWatch Log] Event 100094 stored in success storage (S3)
# [CloudWatch Log] Event 100094 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100094...
# No anomaly detected. Moving on.
#
# Processing event 100095...
# {'eventId': 100095, 'customerId': 'C456', 'salesRepId': 'SR001', 'eventType': None, 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167801', 'platform': 'Android', 'region': 'IN'}
# [CloudWatch Log] Processing event 100095 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100095.
# [CloudWatch Log] Processing event 100095 through Lambda validation...
# [CloudWatch Log] Lambda validation failed: Missing or invalid 'eventType' in event 100095. Sending to DLQ
# [CloudWatch Log] Event 100095 failed Lambda validation. Moving to DLQ.
# [CloudWatch Log] Event 100095 sent to DLQ due to: Lambda Validation.
#
# Processing event 100096...
# {'eventId': 100096, 'customerId': 'C101', 'salesRepId': 'SR003', 'eventType': 'call_logged', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167804', 'platform': 'iOS', 'region': 'IN'}
# [CloudWatch Log] Processing event 100096 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100096.
# [CloudWatch Log] Processing event 100096 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100096.
# [CloudWatch Log] Calculating event 100096...
# [CloudWatch Log] Event 100096 stored in success storage (S3)
# [CloudWatch Log] Event 100096 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100096...
# No anomaly detected. Moving on.
#
# Processing event 100097...
# {'eventId': 100097, 'customerId': 'C123', 'salesRepId': 'SR001', 'eventType': 'inquiry', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167806', 'platform': 'iOS', 'region': 'US'}
# [CloudWatch Log] Processing event 100097 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100097.
# [CloudWatch Log] Processing event 100097 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100097.
# [CloudWatch Log] Calculating event 100097...
# [CloudWatch Log] Event 100097 stored in success storage (S3)
# [CloudWatch Log] Event 100097 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100097...
# No anomaly detected. Moving on.
#
# Processing event 100098...
# {'eventId': 100098, 'customerId': None, 'salesRepId': 'SR004', 'eventType': 'inquiry', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167808', 'platform': 'iOS', 'region': 'IN'}
# [CloudWatch Log] Processing event 100098 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100098.
# [CloudWatch Log] Processing event 100098 through Lambda validation...
# [CloudWatch Log] Lambda validation failed: Missing or invalid 'customerId' in event 100098. Sending to DLQ
# [CloudWatch Log] Event 100098 failed Lambda validation. Moving to DLQ.
# [CloudWatch Log] Event 100098 sent to DLQ due to: Lambda Validation.
#
# Processing event 100099...
# {'eventId': 100099, 'customerId': 'C112', 'salesRepId': 'SR004', 'eventType': 'inquiry', 'eventDetails': 'Details about the event', 'timestamp': '2025-03-23T19:37:34.167810', 'platform': 'iOS', 'region': 'IN'}
# [CloudWatch Log] Processing event 100099 through EventBridge validation...
# [CloudWatch Log] EventBridge rule validation passed for event 100099.
# [CloudWatch Log] Processing event 100099 through Lambda validation...
# [CloudWatch Log] Lambda validation passed for event 100099.
# [CloudWatch Log] Calculating event 100099...
# [CloudWatch Log] Event 100099 stored in success storage (S3)
# [CloudWatch Log] Event 100099 successfully calculated and stored.
# [CloudWatch Log] Detecting anomalies for event 100099...
# No anomaly detected. Moving on.
# [CloudWatch Log]
# Retrying event 100000 from DLQ. Reason: Lambda Validation...
# [CloudWatch Log] Retry attempt 1 for event 100000...
# [CloudWatch Log] Event 100000 cannot be fixed. Moving to failed storage.
# [CloudWatch Log] Event 100000 stored in failed storage (S3)
# [CloudWatch Log] Event 100000 could not be fixed. Keeping in DLQ.
# [CloudWatch Log]
# Retrying event 100002 from DLQ. Reason: Lambda Validation...
# [CloudWatch Log] Retry attempt 1 for event 100002...
# [CloudWatch Log] Event 100002 cannot be fixed. Moving to failed storage.
# [CloudWatch Log] Event 100002 stored in failed storage (S3)
# [CloudWatch Log] Event 100002 could not be fixed. Keeping in DLQ.
# [CloudWatch Log]
# Retrying event 100005 from DLQ. Reason: Lambda Validation...
# [CloudWatch Log] Retry attempt 1 for event 100005...
# [CloudWatch Log] Event 100005 cannot be fixed. Moving to failed storage.
# [CloudWatch Log] Event 100005 stored in failed storage (S3)
# [CloudWatch Log] Event 100005 could not be fixed. Keeping in DLQ.
# [CloudWatch Log]
# Retrying event 100022 from DLQ. Reason: Lambda Validation...
# [CloudWatch Log] Retry attempt 1 for event 100022...
# [CloudWatch Log] Event 100022 cannot be fixed. Moving to failed storage.
# [CloudWatch Log] Event 100022 stored in failed storage (S3)
# [CloudWatch Log] Event 100022 could not be fixed. Keeping in DLQ.
# [CloudWatch Log]
# Retrying event 100040 from DLQ. Reason: Lambda Validation...
# [CloudWatch Log] Retry attempt 1 for event 100040...
# [CloudWatch Log] Event 100040 cannot be fixed. Moving to failed storage.
# [CloudWatch Log] Event 100040 stored in failed storage (S3)
# [CloudWatch Log] Event 100040 could not be fixed. Keeping in DLQ.
# [CloudWatch Log]
# Retrying event 100048 from DLQ. Reason: Lambda Validation...
# [CloudWatch Log] Retry attempt 1 for event 100048...
# [CloudWatch Log] Event 100048 cannot be fixed. Moving to failed storage.
# [CloudWatch Log] Event 100048 stored in failed storage (S3)
# [CloudWatch Log] Event 100048 could not be fixed. Keeping in DLQ.
# [CloudWatch Log]
# Retrying event 100068 from DLQ. Reason: Lambda Validation...
# [CloudWatch Log] Retry attempt 1 for event 100068...
# [CloudWatch Log] Event 100068 cannot be fixed. Moving to failed storage.
# [CloudWatch Log] Event 100068 stored in failed storage (S3)
# [CloudWatch Log] Event 100068 could not be fixed. Keeping in DLQ.
# [CloudWatch Log]
# Retrying event 100069 from DLQ. Reason: Lambda Validation...
# [CloudWatch Log] Retry attempt 1 for event 100069...
# [CloudWatch Log] Event 100069 cannot be fixed. Moving to failed storage.
# [CloudWatch Log] Event 100069 stored in failed storage (S3)
# [CloudWatch Log] Event 100069 could not be fixed. Keeping in DLQ.
# [CloudWatch Log]
# Retrying event 100085 from DLQ. Reason: Lambda Validation...
# [CloudWatch Log] Retry attempt 1 for event 100085...
# [CloudWatch Log] Event 100085 cannot be fixed. Moving to failed storage.
# [CloudWatch Log] Event 100085 stored in failed storage (S3)
# [CloudWatch Log] Event 100085 could not be fixed. Keeping in DLQ.
# [CloudWatch Log]
# Retrying event 100086 from DLQ. Reason: Lambda Validation...
# [CloudWatch Log] Retry attempt 1 for event 100086...
# [CloudWatch Log] Event 100086 cannot be fixed. Moving to failed storage.
# [CloudWatch Log] Event 100086 stored in failed storage (S3)
# [CloudWatch Log] Event 100086 could not be fixed. Keeping in DLQ.
# [CloudWatch Log]
# Retrying event 100087 from DLQ. Reason: Lambda Validation...
# [CloudWatch Log] Retry attempt 1 for event 100087...
# [CloudWatch Log] Event 100087 cannot be fixed. Moving to failed storage.
# [CloudWatch Log] Event 100087 stored in failed storage (S3)
# [CloudWatch Log] Event 100087 could not be fixed. Keeping in DLQ.
# [CloudWatch Log]
# Retrying event 100093 from DLQ. Reason: Lambda Validation...
# [CloudWatch Log] Retry attempt 1 for event 100093...
# [CloudWatch Log] Event 100093 cannot be fixed. Moving to failed storage.
# [CloudWatch Log] Event 100093 stored in failed storage (S3)
# [CloudWatch Log] Event 100093 could not be fixed. Keeping in DLQ.
# [CloudWatch Log]
# Retrying event 100095 from DLQ. Reason: Lambda Validation...
# [CloudWatch Log] Retry attempt 1 for event 100095...
# [CloudWatch Log] Event 100095 cannot be fixed. Moving to failed storage.
# [CloudWatch Log] Event 100095 stored in failed storage (S3)
# [CloudWatch Log] Event 100095 could not be fixed. Keeping in DLQ.
# [CloudWatch Log]
# Retrying event 100098 from DLQ. Reason: Lambda Validation...
# [CloudWatch Log] Retry attempt 1 for event 100098...
# [CloudWatch Log] Event 100098 cannot be fixed. Moving to failed storage.
# [CloudWatch Log] Event 100098 stored in failed storage (S3)
# [CloudWatch Log] Event 100098 could not be fixed. Keeping in DLQ.

# %%
# Print DLQ event IDs
for event in dlq:
    print(event['eventId'])
# Out:
# 100000
# 100002
# 100005
# 100022
# 100040
# 100048
# 100068
# 100069
# 100085
# 100086
# 100087
# 100093
# 100095
# 100098

# %%
storage["success"]
# Out:
# {100001,
#  100003,
#  100004,
#  100006,
#  100007,
#  100008,
#  100009,
#  100010,
#  100011,
#  100012,
#  100013,
#  100014,
#  100015,
#  100016,
#  100017,
#  100018,
#  100019,
#  100020,
#  100021,
#  100023,
#  100024,
#  100025,
#  100026,
#  100027,
#  100028,
#  100029,
#  100030,
#  100031,
#  100032,
#  100033,
#  100034,
#  100035,
#  100036,
#  100037,
#  100038,
#  100039,
#  100041,
#  100042,
#  100043,
#  100044,
#  100045,
#  100046,
#  100047,
#  100049,
#  100050,
#  100051,
#  100052,
#  100053,
#  100054,
#  100055,
#  100056,
#  100057,
#  100058,
#  100059,
#  100060,
#  100061,
#  100062,
#  100063,
#  100064,
#  100065,
#  100066,
#  100067,
#  100070,
#  100071,
#  100072,
#  100073,
#  100074,
#  100075,
#  100076,
#  100077,
#  100078,
#  100079,
#  100080,
#  100081,
#  100082,
#  100083,
#  100084,
#  100088,
#  100089,
#  100090,
#  100091,
#  100092,
#  100094,
#  100096,
#  100097,
#  100099}

# %%
storage["failed"]
# Out:
# {100000,
#  100002,
#  100005,
#  100022,
#  100040,
#  100048,
#  100068,
#  100069,
#  100085,
#  100086,
#  100087,
#  100093,
#  100095,
#  100098}

# %%
event_logs["failed"]
# Out:
# {100000: {'eventId': 100000,
#   'customerId': 'C101',
#   'salesRepId': 'SR004',
#   'eventType': None,
#   'timestamp': '2025-03-23T19:37:34.167516',
#   'platform': 'iOS',
#   'region': 'US',
#   'eventDetails': 'Details about the event'},
#  100002: {'eventId': 100002,
#   'customerId': 'C101',
#   'salesRepId': 'SR003',
#   'eventType': None,
#   'timestamp': '2025-03-23T19:37:34.167526',
#   'platform': 'Android',
#   'region': 'IN',
#   'eventDetails': 'Details about the event'},
#  100005: {'eventId': 100005,
#   'customerId': None,
#   'salesRepId': 'SR001',
#   'eventType': 'ticket_created',
#   'timestamp': '2025-03-23T19:37:34.167533',
#   'platform': 'Android',
#   'region': 'APAC',
#   'eventDetails': 'Details about the event'},
#  100022: {'eventId': 100022,
#   'customerId': None,
#   'salesRepId': 'SR001',
#   'eventType': 'meeting_scheduled',
#   'timestamp': '2025-03-23T19:37:34.167574',
#   'platform': 'iOS',
#   'region': 'IN',
#   'eventDetails': 'Details about the event'},
#  100040: {'eventId': 100040,
#   'customerId': None,
#   'salesRepId': 'SR003',
#   'eventType': 'app_open',
#   'timestamp': '2025-03-23T19:37:34.167616',
#   'platform': 'Android',
#   'region': 'IN',
#   'eventDetails': 'Details about the event'},
#  100048: {'eventId': 100048,
#   'customerId': 'C789',
#   'salesRepId': 'SR003',
#   'eventType': None,
#   'timestamp': '2025-03-23T19:37:34.167638',
#   'platform': 'Android',
#   'region': 'US',
#   'eventDetails': 'Details about the event'},
#  100068: {'eventId': 100068,
#   'customerId': 'C112',
#   'salesRepId': 'SR003',
#   'eventType': None,
#   'timestamp': '2025-03-23T19:37:34.167736',
#   'platform': 'iOS',
#   'region': 'EU',
#   'eventDetails': 'Details about the event'},
#  100069: {'eventId': 100069,
#   'customerId': 'C101',
#   'salesRepId': 'SR001',
#   'eventType': None,
#   'timestamp': '2025-03-23T19:37:34.167738',
#   'platform': 'Android',
#   'region': 'US',
#   'eventDetails': 'Details about the event'},
#  100085: {'eventId': 100085,
#   'customerId': 'C123',
#   'salesRepId': 'SR002',
#   'eventType': None,
#   'timestamp': '2025-03-23T19:37:34.167778',
#   'platform': 'iOS',
#   'region': 'EU',
#   'eventDetails': 'Details about the event'},
#  100086: {'eventId': 100086,
#   'customerId': None,
#   'salesRepId': 'SR001',
#   'eventType': 'app_open',
#   'timestamp': '2025-03-23T19:37:34.167781',
#   'platform': 'iOS',
#   'region': 'APAC',
#   'eventDetails': 'Details about the event'},
#  100087: {'eventId': 100087,
#   'customerId': 'C456',
#   'salesRepId': 'SR003',
#   'eventType': None,
#   'timestamp': '2025-03-23T19:37:34.167783',
#   'platform': 'iOS',
#   'region': 'IN',
#   'eventDetails': 'Details about the event'},
#  100093: {'eventId': 100093,
#   'customerId': None,
#   'salesRepId': 'SR004',
#   'eventType': 'meeting_scheduled',
#   'timestamp': '2025-03-23T19:37:34.167797',
#   'platform': 'Android',
#   'region': 'US',
#   'eventDetails': 'Details about the event'},
#  100095: {'eventId': 100095,
#   'customerId': 'C456',
#   'salesRepId': 'SR001',
#   'eventType': None,
#   'timestamp': '2025-03-23T19:37:34.167801',
#   'platform': 'Android',
#   'region': 'IN',
#   'eventDetails': 'Details about the event'},
#  100098: {'eventId': 100098,
#   'customerId': None,
#   'salesRepId': 'SR004',
#   'eventType': 'inquiry',
#   'timestamp': '2025-03-23T19:37:34.167808',
#   'platform': 'iOS',
#   'region': 'IN',
#   'eventDetails': 'Details about the event'}}
